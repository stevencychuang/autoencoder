# %% [markdown]
# # Convolutional AutoEncoder for Cifar dataset
# # This is modified version from the reference:
# # https://raw.githubusercontent.com/shibuiwilliam/Keras_Autoencoder/master/Cifar_Conv_AutoEncoder.ipynb

# %% [markdown]
# ## Backend and Import

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"
kerasBKED = os.environ["KERAS_BACKEND"] 
print(kerasBKED)
# Out:
# tensorflow

# %%
import keras
from keras.models import load_model
from keras.datasets import cifar10
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, BatchNormalization, Activation
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam
import os
import pickle
import numpy as np

import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
# config.gpu_options.per_process_gpu_memory_fraction = 0.48
set_session(tf.Session(config=config))
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load Cifar10 dataset

# %%
batch_size = 32
num_classes = 10
epochs = 100
saveDir = "./models/"
if not os.path.isdir(saveDir):
    os.makedirs(saveDir)

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
# normalize data
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
# divide x_test into validation and test
x_val = x_test[:7000]
x_test = x_test[7000:]

# %%
print("validation data: {0} \ntest data: {1}".format(x_val.shape, x_test.shape))
# Out:
# validation data: (7000, 32, 32, 3)
# test data: (3000, 32, 32, 3)

# %% [markdown]
# ## Convolutional AutoEncoder

# %%
input_img = Input(shape=(32, 32, 3))
x = Conv2D(64, (3, 3), padding='same')(input_img)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(16, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D((2, 2), padding='same')(x)

shape = K.int_shape(x)
x = Flatten()(x)
x = Dense(16, activation='relu')(x)
encoded = Dense(2, name='latent_vector')(x)
encoder = Model(input_img, encoded)

inputLatent = Input(shape=(tuple(encoded.shape[1:].as_list())), name='decoder_input')

x = Dense(16, activation='relu')(inputLatent)
x = Dense(shape[1] * shape[2] * shape[3])(x)
x = Reshape((shape[1], shape[2], shape[3]))(x)

x = Conv2D(16, (3, 3), padding='same')(inputLatent)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(64, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(3, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
decoded = Activation('sigmoid')(x)
decoder = Model(inputLatent, decoded)

# %%
model = Model(input_img, decoder(encoder(input_img)))
model.compile(optimizer='adam', loss='binary_crossentropy')
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# model_1 (Model)              (None, 4, 4, 16)          25328
# _________________________________________________________________
# model_2 (Model)              (None, 32, 32, 3)         27647
# =================================================================
# Total params: 52,975
# Trainable params: 52,521
# Non-trainable params: 454
# _________________________________________________________________

# %% [markdown]
# ## Train AutoEncoder

# %%
# # load pretrained weights
# model.load_weights(saveDir + "AutoEncoder_Cifar10_Deep_weights.05-0.56-0.56.hdf5")

# %%
es_cb = EarlyStopping(monitor='val_loss', patience=2, verbose=1, mode='auto')
chkpt = saveDir + 'AutoEncoder_Cifar10_Deep_weights.{epoch:02d}-{loss:.2f}-{val_loss:.2f}.hdf5'
cp_cb = ModelCheckpoint(filepath = chkpt, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

# %%
history = model.fit(x_train, x_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_val, x_val),
                    callbacks=[es_cb, cp_cb],
                    shuffle=True)
# Out:
# Train on 50000 samples, validate on 7000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 26s 515us/step - loss: 0.5826 - val_loss: 0.5760
#
# Epoch 00001: val_loss improved from inf to 0.57602, saving model to ./models/AutoEncoder_Cifar10_Deep_weights.01-0.58-0.58.hdf5
# Epoch 2/100
# 50000/50000 [==============================] - 23s 454us/step - loss: 0.5725 - val_loss: 0.5713
#
# Epoch 00002: val_loss improved from 0.57602 to 0.57133, saving model to ./models/AutoEncoder_Cifar10_Deep_weights.02-0.57-0.57.hdf5
# Epoch 3/100
# 50000/50000 [==============================] - 23s 456us/step - loss: 0.5700 - val_loss: 0.5685
#
# Epoch 00003: val_loss improved from 0.57133 to 0.56854, saving model to ./models/AutoEncoder_Cifar10_Deep_weights.03-0.57-0.57.hdf5
# Epoch 4/100
# 50000/50000 [==============================] - 22s 446us/step - loss: 0.5687 - val_loss: 0.5678
#
# Epoch 00004: val_loss improved from 0.56854 to 0.56777, saving model to ./models/AutoEncoder_Cifar10_Deep_weights.04-0.57-0.57.hdf5
# Epoch 5/100
# 50000/50000 [==============================] - 22s 441us/step - loss: 0.5678 - val_loss: 0.5687
#
# Epoch 00005: val_loss did not improve from 0.56777
# Epoch 6/100
# 50000/50000 [==============================] - 22s 444us/step - loss: 0.5672 - val_loss: 0.5670
#
# Epoch 00006: val_loss improved from 0.56777 to 0.56700, saving model to ./models/AutoEncoder_Cifar10_Deep_weights.06-0.57-0.57.hdf5
# Epoch 7/100
# 50000/50000 [==============================] - 22s 438us/step - loss: 0.5665 - val_loss: 0.5669
#
# Epoch 00007: val_loss improved from 0.56700 to 0.56694, saving model to ./models/AutoEncoder_Cifar10_Deep_weights.07-0.57-0.57.hdf5
# Epoch 8/100
# 50000/50000 [==============================] - 22s 445us/step - loss: 0.5661 - val_loss: 0.5657
#
# Epoch 00008: val_loss improved from 0.56694 to 0.56572, saving model to ./models/AutoEncoder_Cifar10_Deep_weights.08-0.57-0.57.hdf5
# Epoch 9/100
# 50000/50000 [==============================] - 22s 443us/step - loss: 0.5657 - val_loss: 0.5656
#
# Epoch 00009: val_loss improved from 0.56572 to 0.56561, saving model to ./models/AutoEncoder_Cifar10_Deep_weights.09-0.57-0.57.hdf5
# Epoch 10/100
# 50000/50000 [==============================] - 22s 441us/step - loss: 0.5654 - val_loss: 0.5650
#
# Epoch 00010: val_loss improved from 0.56561 to 0.56499, saving model to ./models/AutoEncoder_Cifar10_Deep_weights.10-0.57-0.56.hdf5
# Epoch 11/100
# 50000/50000 [==============================] - 23s 456us/step - loss: 0.5651 - val_loss: 0.5655
#
# Epoch 00011: val_loss did not improve from 0.56499
# Epoch 12/100
# 50000/50000 [==============================] - 22s 449us/step - loss: 0.5648 - val_loss: 0.5644
#
# Epoch 00012: val_loss improved from 0.56499 to 0.56442, saving model to ./models/AutoEncoder_Cifar10_Deep_weights.12-0.56-0.56.hdf5
# Epoch 13/100
# 50000/50000 [==============================] - 22s 440us/step - loss: 0.5646 - val_loss: 0.5643
#
# Epoch 00013: val_loss improved from 0.56442 to 0.56434, saving model to ./models/AutoEncoder_Cifar10_Deep_weights.13-0.56-0.56.hdf5
# Epoch 14/100
# 50000/50000 [==============================] - 23s 455us/step - loss: 0.5645 - val_loss: 0.5680
#
# Epoch 00014: val_loss did not improve from 0.56434
# Epoch 15/100
# 50000/50000 [==============================] - 23s 452us/step - loss: 0.5643 - val_loss: 0.5639
#
# Epoch 00015: val_loss improved from 0.56434 to 0.56389, saving model to ./models/AutoEncoder_Cifar10_Deep_weights.15-0.56-0.56.hdf5
# Epoch 16/100
# 50000/50000 [==============================] - 22s 446us/step - loss: 0.5642 - val_loss: 0.5658
#
# Epoch 00016: val_loss did not improve from 0.56389
# Epoch 17/100
# 50000/50000 [==============================] - 21s 429us/step - loss: 0.5640 - val_loss: 0.5645
#
# Epoch 00017: val_loss did not improve from 0.56389
# Epoch 00017: early stopping

# %% [markdown]
# ## Evaluate with test dataset

# %%
score = model.evaluate(x_test, x_test, verbose=1)
print(score)
# Out:
# 3000/3000 [==============================] - 0s 118us/step
# 0.563701251188914

# %% [markdown]
# ## Visualize original image and reconstructed image

# %%
c10test = model.predict(x_test)
c10val = model.predict(x_val)

# %%
print("Cifar10_test: {0}\nCifar10_val: {1}".format(np.average(c10test), np.average(c10val)))
# Out:
# Cifar10_test: 0.4869609475135803
# Cifar10_val: 0.4903954565525055

# %%
# definition to show original image and reconstructed image
def showOrigDec(orig, dec, num=10):
    import matplotlib.pyplot as plt
    n = num
    plt.figure(figsize=(20, 4))

    for i in range(n):
        # display original
        ax = plt.subplot(2, n, i+1)
        plt.imshow(orig[i].reshape(32, 32, 3))
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # display reconstruction
        ax = plt.subplot(2, n, i +1 + n)
        plt.imshow(dec[i].reshape(32, 32, 3))
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# %%
showOrigDec(x_test, c10test)

# %%
showOrigDec(x_test[100:], c10test[100:])

# %%
showOrigDec(x_test[200:], c10test[200:])

# %%
showOrigDec(x_val, c10val)

# %%
showOrigDec(x_val[100:], c10val[100:])

# %%
showOrigDec(x_val[200:], c10val[200:])

# %% [markdown]
# ## Try the Convolutional AutoEncoder on Cifar100

# %% [markdown]
# ## Load cifar100 dataset

# %%
from keras.datasets import cifar100

(x_train100, y_train100), (x_test100, y_test100) = cifar100.load_data()

# %%
# normalize data
x_train100 = x_train100.astype('float32')
x_test100 = x_test100.astype('float32')
x_train100 /= 255
x_test100 /= 255

# %%
print('x_train100 shape:', x_train100.shape)
print(x_train100.shape[0], 'train samples')
print(x_test100.shape[0], 'test samples')
# Out:
# x_train100 shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
score = model.evaluate(x_train100, x_train100, verbose=1)
print(score)
# Out:
# 50000/50000 [==============================] - 6s 115us/step
# 0.5416103220558166

# %%
score = model.evaluate(x_test100, x_test100, verbose=1)
print(score)
# Out:
# 10000/10000 [==============================] - 1s 118us/step
# 0.5408208972930908

# %% [markdown]
# ## Autoencoder on Cifar100 dateset

# %%
c100train = model.predict(x_train100)
c100test = model.predict(x_test100)

# %%
print("Cifar100 train: {0} \nCifar100 test: {1}"
      .format(np.average(c100train), np.average(c100test)))
# Out:
# Cifar100 train: 0.4904041588306427
# Cifar100 test: 0.49159538745880127

# %%
showOrigDec(x_train100, c100train)

# %%
showOrigDec(x_train100[100:], c100train[100:])

# %%
showOrigDec(x_train100[200:], c100train[200:])

# %%
showOrigDec(x_test100, c100test)

# %%
showOrigDec(x_test100[100:], c100test[100:])

# %%
showOrigDec(x_test100[200:], c100test[200:])

# %%
print(encoded)
# Out:
# Tensor("max_pooling2d_3/MaxPool:0", shape=(?, 4, 4, 16), dtype=float32)

# %%
print(inputLatent)
print(type(inputLatent))
# Out:
# Tensor("decoder_input:0", shape=(?, 4, 4, 16), dtype=float32)
# <class 'tensorflow.python.framework.ops.Tensor'>
