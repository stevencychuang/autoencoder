# %%
from time import time
import numpy as np
numSeed = 42
np.random.seed(numSeed)
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
from keras.layers import Input, Dense, Lambda
from keras.models import Model
from keras import backend
from keras import metrics
from keras.datasets import cifar10

from util import plotScatterDecode, plotProgress, plotCompDecode, plotScatterEncode, addNoise
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load the datasets

# %%
(xTrain, _), (xTest, yTest) = cifar10.load_data()
yTest = np.squeeze(yTest, axis=1)
xTrain = xTrain.astype('float32') / 255.
xTest = xTest.astype('float32') / 255.
numTrain = len(xTrain)
numTest = len(xTest)
dimInput = np.prod(xTrain.shape[1:])
sizeDigit = xTrain.shape[1]

xTrain = xTrain.reshape((numTrain, dimInput))
xTest = xTest.reshape((numTest, dimInput))
print(xTrain.shape)
print(xTest.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 78s 0us/step
# (50000, 3072)
# (10000, 3072)

# %% [markdown]
# ## Declare the parameters and layers

# %%
numEpochs = 50
sizeBatch = 32
dimInter1 = 256
dimInter2 = 64
dimInter3 = 16
dimEncode = 2
stdEps = 1.0 
ratRecon = 0.998
nameOptim = 'adam'

# %% [markdown]
# ## Construct the encoder and decoder

# %%
layEncInt1 = Dense(dimInter1, activation='relu')
layEncInt2 = Dense(dimInter2, activation='relu')
layEncInt3 = Dense(dimInter3, activation='relu')
layMean = Dense(dimEncode)
laySigma = Dense(dimEncode)
layDecInt1 = Dense(dimInter3, activation='relu')
layDecInt2 = Dense(dimInter2, activation='relu')
layDecInt3 = Dense(dimInter1, activation='relu')
layDecode = Dense(dimInput, activation='sigmoid')

inputs = Input(shape=(dimInput,))
interEncode1 = layEncInt1(inputs)
interEncode2 = layEncInt2(interEncode1)
interEncode3 = layEncInt3(interEncode2)
zMean = layMean(interEncode3)
zSigmaLog = laySigma(interEncode3) # log for linear dense

def sampling(args):
    zMean, zSigmaLog = args
    epsilon = backend.random_normal(shape=(backend.shape(zMean)[0], dimEncode),
                              mean=0., stddev=stdEps)
    return zMean + backend.exp(zSigmaLog) * epsilon

# note that "output_shape" isn't necessary with the TensorFlow backend
# so you could write `Lambda(sampling)([z_mean, z_log_sigma])`
# z = Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_sigma])
z = Lambda(sampling)([zMean, zSigmaLog])
encoder = Model(inputs, z)

inputZ = Input(shape=(dimEncode,))
interDecode1 = layDecInt1(inputZ)
interDecode2 = layDecInt2(interDecode1)
interDecode3 = layDecInt3(interDecode2)
decode = layDecode(interDecode3)
decoder = Model(inputZ, decode)

# %% [markdown]
# ## Construct the autoencoder

# %%
vae = Model(inputs, decoder(encoder(inputs)))
vae.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# model_1 (Model)              (None, 2)                 397772
# _________________________________________________________________
# model_2 (Model)              (None, 3072)              400824
# =================================================================
# Total params: 798,596
# Trainable params: 798,596
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compile and train

# %%
def lossVAE(zMean, zSigmaLog):
    def loss(tensorInput, tensorDecode):
        lossRecon =  metrics.binary_crossentropy(tensorInput, tensorDecode)
        lossKL = - 0.5 * backend.sum(1 + 2 * zSigmaLog - backend.square(zMean) - backend.square(backend.exp(zSigmaLog)), axis=-1)
#         lossKL = - 0.5 * K.mean(1 + zSigmaLog - K.square(zMean) - K.exp(zSigmaLog), axis=-1)
        return ratRecon * lossRecon + (1 - ratRecon) * lossKL
    return loss


vae.compile(optimizer=nameOptim, loss=lossVAE(zMean, zSigmaLog))
tic = time()
history = vae.fit(xTrain, xTrain,
                epochs=numEpochs,
                batch_size=sizeBatch,
                shuffle=True,
                validation_data=(xTest, xTest))
timeTrain = time() - tic
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 14s 286us/step - loss: 0.6879 - val_loss: 0.6881
# Epoch 2/50
# 50000/50000 [==============================] - 12s 234us/step - loss: 0.6878 - val_loss: 0.6880
# Epoch 3/50
# 50000/50000 [==============================] - 12s 232us/step - loss: 0.6878 - val_loss: 0.6880
# Epoch 4/50
# 50000/50000 [==============================] - 12s 238us/step - loss: 0.6878 - val_loss: 0.6880
# Epoch 5/50
# 50000/50000 [==============================] - 12s 230us/step - loss: 0.6878 - val_loss: 0.6880
# Epoch 6/50
# 50000/50000 [==============================] - 12s 230us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 7/50
# 50000/50000 [==============================] - 12s 232us/step - loss: 0.6877 - val_loss: 0.6881
# Epoch 8/50
# 50000/50000 [==============================] - 12s 249us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 9/50
# 50000/50000 [==============================] - 13s 255us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 10/50
# 50000/50000 [==============================] - 12s 241us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 11/50
# 50000/50000 [==============================] - 12s 243us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 12/50
# 50000/50000 [==============================] - 12s 237us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 13/50
# 50000/50000 [==============================] - 13s 253us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 14/50
# 50000/50000 [==============================] - 13s 250us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 15/50
# 50000/50000 [==============================] - 12s 233us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 16/50
# 50000/50000 [==============================] - 12s 232us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 17/50
# 50000/50000 [==============================] - 11s 230us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 18/50
# 50000/50000 [==============================] - 12s 231us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 19/50
# 50000/50000 [==============================] - 12s 238us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 20/50
# 50000/50000 [==============================] - 12s 248us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 21/50
# 50000/50000 [==============================] - 11s 229us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 22/50
# 50000/50000 [==============================] - 12s 230us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 23/50
# 50000/50000 [==============================] - 12s 242us/step - loss: 0.6877 - val_loss: 0.6881
# Epoch 24/50
# 50000/50000 [==============================] - 13s 252us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 25/50
# 50000/50000 [==============================] - 12s 237us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 26/50
# 50000/50000 [==============================] - 12s 231us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 27/50
# 50000/50000 [==============================] - 12s 240us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 28/50
# 50000/50000 [==============================] - 12s 235us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 29/50
# 50000/50000 [==============================] - 11s 229us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 30/50
# 50000/50000 [==============================] - 11s 229us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 31/50
# 50000/50000 [==============================] - 12s 231us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 32/50
# 50000/50000 [==============================] - 12s 234us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 33/50
# 50000/50000 [==============================] - 12s 241us/step - loss: 0.6877 - val_loss: 0.6881
# Epoch 34/50
# 50000/50000 [==============================] - 12s 247us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 35/50
# 50000/50000 [==============================] - 12s 235us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 36/50
# 50000/50000 [==============================] - 12s 243us/step - loss: 0.6877 - val_loss: 0.6881
# Epoch 37/50
# 50000/50000 [==============================] - 12s 231us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 38/50
# 50000/50000 [==============================] - 12s 232us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 39/50
# 50000/50000 [==============================] - 12s 241us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 40/50
# 50000/50000 [==============================] - 12s 237us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 41/50
# 50000/50000 [==============================] - 12s 236us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 42/50
# 50000/50000 [==============================] - 12s 237us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 43/50
# 50000/50000 [==============================] - 12s 238us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 44/50
# 50000/50000 [==============================] - 12s 242us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 45/50
# 50000/50000 [==============================] - 12s 240us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 46/50
# 50000/50000 [==============================] - 12s 240us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 47/50
# 50000/50000 [==============================] - 12s 241us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 48/50
# 50000/50000 [==============================] - 12s 240us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 49/50
# 50000/50000 [==============================] - 13s 256us/step - loss: 0.6877 - val_loss: 0.6880
# Epoch 50/50
# 50000/50000 [==============================] - 12s 246us/step - loss: 0.6877 - val_loss: 0.6880

# %% [markdown]
# ## Show the historical training progress

# %%
print("traing consumed: " + str(timeTrain) + " seconds")
plotProgress(history)
# Out:
# traing consumed: 599.182953119278 seconds

# %% [markdown]
# ## Get the encoding and decoding results of testing data, and get the mean/std of the encoding

# %%
# encode and decode some digits
# note that we take them from the *test* set
encodeTest = encoder.predict(xTest)
decodeTest = decoder.predict(encodeTest)
meanEncTest = np.mean(encodeTest, axis=0)
stdEncTest = np.std(encodeTest, axis=0)

# %% [markdown]
# ## Compare original digitals with the decoding results

# %%
plotCompDecode(xTest, decodeTest, sizeDigit = (32, 32, 3))

# %% [markdown]
# ## Plot the scatter of the encoding space

# %%
xlim = (meanEncTest[0] - 4*stdEncTest[0], meanEncTest[0] + 4*stdEncTest[0])
ylim = (meanEncTest[1] - 4*stdEncTest[1], meanEncTest[1] + 4*stdEncTest[1])

plotScatterEncode(encodeTest, yTest, xlim, ylim, numShow=10000)
scoreSilh = silhouette_score(encodeTest, yTest)

# %% [markdown]
# ## Plot the decoding results from the encoding scatter

# %%
# display a 2D manifold of the digits
plotScatterDecode(decoder, (32,32,3), xlim, ylim)

# %%
print(timeTrain, history.history["loss"][numEpochs-1], history.history["val_loss"][numEpochs-1], scoreSilh)
# Out:
# 11.620586633682251 0.6640547546768188 0.6469828006744385 -0.12210027
