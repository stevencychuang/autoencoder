# %%
from time import time
import numpy as np
numSeed = 42
np.random.seed(numSeed)
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
from keras.layers import Input, Dense, Lambda
from keras.models import Model
from keras import backend as K
from keras import metrics
from keras.datasets import mnist

from util import plotScatterDecode, plotProgress, plotCompDecode, plotScatterEncode, addNoise
from dataPreproc import *
import pickle
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load the datasets

# %%
with open('./Img_list.pkl', 'rb') as f:
    img_list_all = pickle.load(f)
img_width = 245
img_height = 205
    
# Special downsampling for the videos which are with over 300 frames
img_list_all[0] = img_list_all[0][160:160]
img_list_all[8] = img_list_all[8][110:210]
img_list_all[9] = img_list_all[9][116:216]

# List to numpy array and get corresponding labels
data, prog = list2NumpyArr(img_list_all, img_height, img_width)
data = data[:, 50:150, 60:200] # 100 x 140
labelList, labelSet = getLab(img_list_all)

xTrain = data
xTest = data
yTrain = labelList
yTest = labelList
# (xTrain, _), (xTest, yTest) = mnist.load_data()
xTrain = xTrain.astype('float32') / 255.
xTest = xTest.astype('float32') / 255.
numTrain = len(xTrain)
numTest = len(xTest)
dimInput = np.prod(xTrain.shape[1:])
sizeDigit = xTrain.shape[1]

xTrain = xTrain.reshape((numTrain, dimInput))
xTest = xTest.reshape((numTest, dimInput))
print(xTrain.shape)
print(xTest.shape)
# Out:
# 0
# 96
# S_0507F_xxC07S
# 140
# C_0430F_04C
# 103
# R_0430F_13R-2
# 84
# R_0430F_14R-2
# 62
# S_0430F_16S
# 63
# S_0430F_18S
# 141
# C_0430F_05C
# 100
# C_0208_Fan06
# 100
# C_0208_Fan06
# 87
# C_0430F_02C
# 87
# C_0430F_02C
# 147
# C_0430F_06C
# 138
# C_0502F_02C
# 144
# C_0502F_04C05S
# 139
# C_0502F_06C07S
# 163
# C_0502F_08C09S
# 132
# C_0502F_10R11C12S
# 112
# C_0502F_13R14C15S
# 117
# C_0507F_xxC07S
# 128
# R_0430F_07R
# 108
# R_0430F_12R
# 113
# R_0430F_15R-2
# 117
# R_0502F_01R
# 125
# R_0502F_03R
# 110
# R_0502F_10R11C12S
# 115
# R_0502F_13R14C15S
# 113
# R_0502F_16R17C
# 68
# S_0419F_3S
# 54
# S_0430F_17S
# 65
# S_0502F_04C05S
# 92
# S_0502F_06C07S
# 70
# S_0502F_08C09S
# 63
# S_0502F_10R11C12S
# 52
# S_0502F_13R14C15S
# 81
# C_0419F_1C
# 83
# R_0419F_2R
# (3712, 14000)
# (3712, 14000)

# %% [markdown]
# ## Declare the parameters and layers

# %%
numEpochs = 200
sizeBatch = 32
dimInter = 64
dimEncode = 2
stdEps = 1.0 
ratRecon = 1
nameOptim = 'adam'

# %% [markdown]
# ## Construct the encoder and decoder

# %%
layEncInt = Dense(dimInter, activation='relu')
layMean = Dense(dimEncode)
laySigma = Dense(dimEncode)
layDecInt = Dense(dimInter, activation='relu')
layDecode = Dense(dimInput, activation='sigmoid')

inputs = Input(shape=(dimInput,))
interEncode = layEncInt(inputs)
zMean = layMean(interEncode)
zSigmaLog = laySigma(interEncode) # log for linear dense

def sampling(args):
    zMean, zSigmaLog = args
    epsilon = K.random_normal(shape=(K.shape(zMean)[0], dimEncode),
                              mean=0., stddev=stdEps)
    return zMean + K.exp(zSigmaLog) * epsilon

# note that "output_shape" isn't necessary with the TensorFlow backend
# so you could write `Lambda(sampling)([z_mean, z_log_sigma])`
# z = Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_sigma])
z = Lambda(sampling)([zMean, zSigmaLog])
encoder = Model(inputs, z)

inputZ = Input(shape=(dimEncode,))
interDecode = layDecInt(inputZ)
decode = layDecode(interDecode)
decoder = Model(inputZ, decode)

# %% [markdown]
# ## Construct the autoencoder

# %%
vae = Model(inputs, decoder(encoder(inputs)))
vae.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 14000)             0
# _________________________________________________________________
# model_1 (Model)              (None, 2)                 896324
# _________________________________________________________________
# model_2 (Model)              (None, 14000)             910192
# =================================================================
# Total params: 1,806,516
# Trainable params: 1,806,516
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compile and train

# %%
def lossVAE(zMean, zSigmaLog):
    def loss(tensorInput, tensorDecode):
        lossRecon =  metrics.binary_crossentropy(tensorInput, tensorDecode)
        lossKL = - 0.5 * K.sum(1 + 2 * zSigmaLog - K.square(zMean) - K.square(K.exp(zSigmaLog)), axis=-1)
#         lossKL = - 0.5 * K.mean(1 + zSigmaLog - K.square(zMean) - K.exp(zSigmaLog), axis=-1)
        return ratRecon * lossRecon + (1 - ratRecon) * lossKL
    return loss


vae.compile(optimizer=nameOptim, loss=lossVAE(zMean, zSigmaLog))
tic = time()
history = vae.fit(xTrain, xTrain,
                epochs=numEpochs,
                batch_size=sizeBatch,
                shuffle=True,
                validation_data=(xTest, xTest))
timeTrain = time() - tic
# Out:
# Train on 3712 samples, validate on 3712 samples
# Epoch 1/200
# 3712/3712 [==============================] - 3s 691us/step - loss: 0.6188 - val_loss: 0.5948
# Epoch 2/200
# 3712/3712 [==============================] - 1s 218us/step - loss: 0.5919 - val_loss: 0.5886
# Epoch 3/200
# 3712/3712 [==============================] - 1s 214us/step - loss: 0.5865 - val_loss: 0.5823
# Epoch 4/200
# 3712/3712 [==============================] - 1s 216us/step - loss: 0.5813 - val_loss: 0.5804
# Epoch 5/200
# 3712/3712 [==============================] - 1s 214us/step - loss: 0.5792 - val_loss: 0.5793
# Epoch 6/200
# 3712/3712 [==============================] - 1s 217us/step - loss: 0.5776 - val_loss: 0.5776
# Epoch 7/200
# 3712/3712 [==============================] - 1s 220us/step - loss: 0.5760 - val_loss: 0.5745
# Epoch 8/200
# 3712/3712 [==============================] - 1s 230us/step - loss: 0.5752 - val_loss: 0.5741
# Epoch 9/200
# 3712/3712 [==============================] - 1s 216us/step - loss: 0.5738 - val_loss: 0.5738
# Epoch 10/200
# 3712/3712 [==============================] - 1s 228us/step - loss: 0.5734 - val_loss: 0.5725
# Epoch 11/200
# 3712/3712 [==============================] - 1s 215us/step - loss: 0.5734 - val_loss: 0.5727
# Epoch 12/200
# 3712/3712 [==============================] - 1s 214us/step - loss: 0.5723 - val_loss: 0.5712
# Epoch 13/200
# 3712/3712 [==============================] - 1s 218us/step - loss: 0.5711 - val_loss: 0.5707
# Epoch 14/200
# 3712/3712 [==============================] - 1s 219us/step - loss: 0.5708 - val_loss: 0.5730
# Epoch 15/200
# 3712/3712 [==============================] - 1s 214us/step - loss: 0.5703 - val_loss: 0.5699
# Epoch 16/200
# 3712/3712 [==============================] - 1s 220us/step - loss: 0.5699 - val_loss: 0.5686
# Epoch 17/200
# 3712/3712 [==============================] - 1s 220us/step - loss: 0.5690 - val_loss: 0.5687
# Epoch 18/200
# 3712/3712 [==============================] - 1s 214us/step - loss: 0.5685 - val_loss: 0.5680
# Epoch 19/200
# 3712/3712 [==============================] - 1s 214us/step - loss: 0.5681 - val_loss: 0.5684
# Epoch 20/200
# 3712/3712 [==============================] - 1s 214us/step - loss: 0.5673 - val_loss: 0.5670
# Epoch 21/200
# 3712/3712 [==============================] - 1s 211us/step - loss: 0.5673 - val_loss: 0.5665
# Epoch 22/200
# 3712/3712 [==============================] - 1s 211us/step - loss: 0.5659 - val_loss: 0.5646
# Epoch 23/200
# 3712/3712 [==============================] - 1s 216us/step - loss: 0.
200
# 3712/3712 [==============================] - 1s 229us/step - loss: 0.5431 - val_loss: 0.5430
# Epoch 186/200
# 3712/3712 [==============================] - 1s 257us/step - loss: 0.5428 - val_loss: 0.5432
# Epoch 187/200
# 3712/3712 [==============================] - 1s 232us/step - loss: 0.5428 - val_loss: 0.5432
# Epoch 188/200
# 3712/3712 [==============================] - 1s 222us/step - loss: 0.5428 - val_loss: 0.5425
# Epoch 189/200
# 3712/3712 [==============================] - 1s 224us/step - loss: 0.5425 - val_loss: 0.5441
# Epoch 190/200
# 3712/3712 [==============================] - 1s 228us/step - loss: 0.5425 - val_loss: 0.5423
# Epoch 191/200
# 3712/3712 [==============================] - 1s 229us/step - loss: 0.5433 - val_loss: 0.5429
# Epoch 192/200
# 3712/3712 [==============================] - 1s 251us/step - loss: 0.5428 - val_loss: 0.5420
# Epoch 193/200
# 3712/3712 [==============================] - 1s 230us/step - loss: 0.5432 - val_loss: 0.5422
# Epoch 194/200
# 3712/3712 [==============================] - 1s 223us/step - loss: 0.5421 - val_loss: 0.5417
# Epoch 195/200
# 3712/3712 [==============================] - 1s 229us/step - loss: 0.5428 - val_loss: 0.5414
# Epoch 196/200
# 3712/3712 [==============================] - 1s 268us/step - loss: 0.5427 - val_loss: 0.5414
# Epoch 197/200
# 3712/3712 [==============================] - 1s 231us/step - loss: 0.5423 - val_loss: 0.5414
# Epoch 198/200
# 3712/3712 [==============================] - 1s 216us/step - loss: 0.5423 - val_loss: 0.5437
# Epoch 199/200
# 3712/3712 [==============================] - 1s 222us/step - loss: 0.5424 - val_loss: 0.5415
# Epoch 200/200
# 3712/3712 [==============================] - 1s 217us/step - loss: 0.5423 - val_loss: 0.5421

# %% [markdown]
# ## Show the historical training progress

# %%
print("traing consumed: " + str(timeTrain) + " seconds")
plotProgress(history)
# Out:
# traing consumed: 176.4279317855835 seconds

# %% [markdown]
# ## Get the encoding and decoding results of testing data, and get the mean/std of the encoding

# %%
# encode and decode some digits
# note that we take them from the *test* set
encodeTest = encoder.predict(xTest)
decodeTest = decoder.predict(encodeTest)
meanEncTest = np.mean(encodeTest, axis=0)
stdEncTest = np.std(encodeTest, axis=0)

# %% [markdown]
# ## Compare original digitals with the decoding results

# %%
plotCompDecode(xTest, decodeTest, sizeDigit=(100, 140))

# %% [markdown]
# ## Plot the scatter of the encoding space

# %%
xlim = (meanEncTest[0] - 3*stdEncTest[0], meanEncTest[0] + 3*stdEncTest[0])
ylim = (meanEncTest[1] - 3*stdEncTest[1], meanEncTest[1] + 3*stdEncTest[1])

plotScatterEncode(encodeTest, yTest, xlim, ylim, sizeFont=20)
scoreSilh = silhouette_score(encodeTest, yTest)

# %%
plotScatterEncode(encodeTest, prog, xlim, ylim, sizeFont=1)

# %% [markdown]
# ## Plot the decoding results from the encoding scatter

# %%
# display a 2D manifold of the digits
plotScatterDecode(decoder, (100, 140), xlim, ylim)

# %%
print(timeTrain, history.history["loss"][numEpochs-1], history.history["val_loss"][numEpochs-1], scoreSilh)
# Out:
# 176.4279317855835 0.5423121519129852 0.5420818878658886 -0.23111188
