# %%
from time import time
import numpy as np
numSeed = 42
np.random.seed(numSeed)
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.datasets import mnist

from util import plotScatterDecode, plotProgress, plotCompDecode, plotScatterEncode
# Out:
# c:\users\user\anaconda3\envs\py36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ## Load the datasets

# %%
(xTrain, _), (xTest, yTest) = mnist.load_data()
xTrain = xTrain.astype('float32') / 255.
xTest = xTest.astype('float32') / 255.
numTrain = len(xTrain)
numTest = len(xTest)
dimInput = np.prod(xTrain.shape[1:])
sizeDigit = xTrain.shape[1]

xTrain = xTrain.reshape(numTrain, dimInput)
xTest = xTest.reshape(numTest, dimInput)
print(xTrain.shape)
print(xTest.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %% [markdown]
# ## Declare the parameters

# %%
numEpochs = 50
sizeBatch = 32
dimEncode = 2
nameOptim = 'adam'

# %% [markdown]
# ## Construct the encoder and decoder

# %%
layEncode = Dense(dimEncode, activation='relu')
layDecode = Dense(dimInput, activation='sigmoid')

inputs = Input(shape=(dimInput,))
latentEncode = layEncode(inputs)
encoder = Model(inputs, latentEncode)

inputLatent = Input(shape=(dimEncode,))
decode = layDecode(inputLatent)
decoder = Model(inputLatent, decode)

# %% [markdown]
# ## Construct the autoencoder

# %%
autoencoder = Model(inputs, decoder(encoder(inputs)))
autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# model_1 (Model)              (None, 2)                 1570
# _________________________________________________________________
# model_2 (Model)              (None, 784)               2352
# =================================================================
# Total params: 3,922
# Trainable params: 3,922
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compile and train

# %%
autoencoder.compile(optimizer=nameOptim, loss='binary_crossentropy')
tic = time()
history = autoencoder.fit(xTrain, xTrain,
                epochs=numEpochs,
                batch_size=sizeBatch,
#                 shuffle=True,
                validation_data=(xTest, xTest))
timeTrain = time() - tic
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 6s 107us/step - loss: 0.2660 - val_loss: 0.2397
# Epoch 2/50
# 60000/60000 [==============================] - 5s 85us/step - loss: 0.2373 - val_loss: 0.2341
# Epoch 3/50
# 60000/60000 [==============================] - 5s 84us/step - loss: 0.2328 - val_loss: 0.2304
# Epoch 4/50
# 60000/60000 [==============================] - 5s 84us/step - loss: 0.2296 - val_loss: 0.2278
# Epoch 5/50
# 60000/60000 [==============================] - 5s 83us/step - loss: 0.2277 - val_loss: 0.2266
# Epoch 6/50
# 60000/60000 [==============================] - 5s 87us/step - loss: 0.2269 - val_loss: 0.2259
# Epoch 7/50
# 60000/60000 [==============================] - 5s 86us/step - loss: 0.2266 - val_loss: 0.2256
# Epoch 8/50
# 60000/60000 [==============================] - 5s 86us/step - loss: 0.2264 - val_loss: 0.2256
# Epoch 9/50
# 60000/60000 [==============================] - 5s 86us/step - loss: 0.2263 - val_loss: 0.2254
# Epoch 10/50
# 60000/60000 [==============================] - 5s 85us/step - loss: 0.2263 - val_loss: 0.2254
# Epoch 11/50
# 60000/60000 [==============================] - 5s 85us/step - loss: 0.2262 - val_loss: 0.2254
# Epoch 12/50
# 60000/60000 [==============================] - 5s 87us/step - loss: 0.2261 - val_loss: 0.2253
# Epoch 13/50
# 60000/60000 [==============================] - 5s 87us/step - loss: 0.2261 - val_loss: 0.2253
# Epoch 14/50
# 60000/60000 [==============================] - 5s 88us/step - loss: 0.2261 - val_loss: 0.2252
# Epoch 15/50
# 60000/60000 [==============================] - 5s 87us/step - loss: 0.2260 - val_loss: 0.2254
# Epoch 16/50
# 60000/60000 [==============================] - 5s 87us/step - loss: 0.2260 - val_loss: 0.2252
# Epoch 17/50
# 60000/60000 [==============================] - 5s 86us/step - loss: 0.2260 - val_loss: 0.2252
# Epoch 18/50
# 60000/60000 [==============================] - 5s 85us/step - loss: 0.2260 - val_loss: 0.2251
# Epoch 19/50
# 60000/60000 [==============================] - 5s 87us/step - loss: 0.2260 - val_loss: 0.2251
# Epoch 20/50
# 60000/60000 [==============================] - 5s 87us/step - loss: 0.2260 - val_loss: 0.2251
# Epoch 21/50
# 60000/60000 [==============================] - 5s 87us/step - loss: 0.2259 - val_loss: 0.2251
# Epoch 22/50
# 60000/60000 [==============================] - 5s 87us/step - loss: 0.2259 - val_loss: 0.2250
# Epoch 23/50
# 60000/60000 [==============================] - 5s 87us/step - loss: 0.2259 - val_loss: 0.2250
# Epoch 24/50
# 60000/60000 [==============================] - 5s 87us/step - loss: 0.2259 - val_loss: 0.2250
# Epoch 25/50
# 60000/60000 [==============================] - 5s 87us/step - loss: 0.2259 - val_loss: 0.2251
# Epoch 26/50
# 60000/60000 [==============================] - 5s 86us/step - loss: 0.2259 - val_loss: 0.2251
# Epoch 27/50
# 60000/60000 [==============================] - 5s 85us/step - loss: 0.2258 - val_loss: 0.2250
# Epoch 28/50
# 60000/60000 [==============================] - 5s 86us/step - loss: 0.2258 - val_loss: 0.2250
# Epoch 29/50
# 60000/60000 [==============================] - 5s 82us/step - loss: 0.2258 - val_loss: 0.2249
# Epoch 30/50
# 60000/60000 [==============================] - 5s 85us/step - loss: 0.2258 - val_loss: 0.2249
# Epoch 31/50
# 60000/60000 [==============================] - 5s 86us/step - loss: 0.2258 - val_loss: 0.2249
# Epoch 32/50
# 60000/60000 [==============================] - 5s 83us/step - loss: 0.2258 - val_loss: 0.2248
# Epoch 33/50
# 60000/60000 [==============================] - 5s 87us/step - loss: 0.2258 - val_loss: 0.2250
# Epoch 34/50
# 60000/60000 [==============================] - 5s 88us/step - loss: 0.2258 - val_loss: 0.2249
# Epoch 35/50
# 60000/60000 [==============================] - 5s 89us/step - loss: 0.2257 - val_loss: 0.2249
# Epoch 36/50
# 60000/60000 [==============================] - 5s 86us/step - loss: 0.2257 - val_loss: 0.2249
# Epoch 37/50
# 60000/60000 [==============================] - 5s 89us/step - loss: 0.2257 - val_loss: 0.2250
# Epoch 38/50
# 60000/60000 [==============================] - 5s 86us/step - loss: 0.2257 - val_loss: 0.2249
# Epoch 39/50
# 60000/60000 [==============================] - 5s 84us/step - loss: 0.2257 - val_loss: 0.2249
# Epoch 40/50
# 60000/60000 [==============================] - 5s 85us/step - loss: 0.2257 - val_loss: 0.2249
# Epoch 41/50
# 60000/60000 [==============================] - 5s 83us/step - loss: 0.2257 - val_loss: 0.2250
# Epoch 42/50
# 60000/60000 [==============================] - 5s 82us/step - loss: 0.2257 - val_loss: 0.2249
# Epoch 43/50
# 60000/60000 [==============================] - 5s 84us/step - loss: 0.2257 - val_loss: 0.2249
# Epoch 44/50
# 60000/60000 [==============================] - 5s 84us/step - loss: 0.2257 - val_loss: 0.2248
# Epoch 45/50
# 60000/60000 [==============================] - 5s 83us/step - loss: 0.2257 - val_loss: 0.2248
# Epoch 46/50
# 60000/60000 [==============================] - 5s 86us/step - loss: 0.2257 - val_loss: 0.2249
# Epoch 47/50
# 60000/60000 [==============================] - 5s 83us/step - loss: 0.2257 - val_loss: 0.2249
# Epoch 48/50
# 60000/60000 [==============================] - 5s 87us/step - loss: 0.2257 - val_loss: 0.2251
# Epoch 49/50
# 60000/60000 [==============================] - 5s 86us/step - loss: 0.2257 - val_loss: 0.2248
# Epoch 50/50
# 60000/60000 [==============================] - 5s 84us/step - loss: 0.2257 - val_loss: 0.2248

# %% [markdown]
# ## Show the historical training progress

# %%
print("traing consumed: " + str(timeTrain) + " seconds")
plotProgress(history)
# Out:
# traing consumed: 258.23344683647156 seconds

# %% [markdown]
# ## Get the encoding and decoding results of testing data, and get the mean/std of the encoding

# %%
# encode and decode some digits
# note that we take them from the *test* set
encodeTest = encoder.predict(xTest)
decodeTest = decoder.predict(encodeTest)
meanEncTest = np.mean(encodeTest, axis=0)
stdEncTest = np.std(encodeTest, axis=0)

# %% [markdown]
# ## Compare original digitals with the decoding results

# %%
plotCompDecode(xTest, decodeTest)

# %% [markdown]
# ## Plot the scatter of the encoding space

# %%
xlim = (meanEncTest[0] - 4*stdEncTest[0], meanEncTest[0] + 4*stdEncTest[0])
ylim = (meanEncTest[1] - 4*stdEncTest[1], meanEncTest[1] + 4*stdEncTest[1])

plotScatterEncode(encodeTest, yTest, xlim, ylim)
scoreSilh = silhouette_score(encodeTest, yTest)

# %% [markdown]
# ## Plot the decoding results from the encoding scatter

# %%
# display a 2D manifold of the digits
plotScatterDecode(decoder, sizeDigit, xlim, ylim)

# %%
print(timeTrain, history.history["loss"][numEpochs-1], history.history["val_loss"][numEpochs-1], scoreSilh)
# Out:
# 258.23344683647156 0.22572707008520762 0.22475861315727233 -0.0064682555
