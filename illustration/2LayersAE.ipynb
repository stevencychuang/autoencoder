# %%
from time import time
import numpy as np
numSeed = 42
np.random.seed(numSeed)
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.datasets import mnist

from util import plotScatterDecode, plotProgress, plotCompDecode, plotScatterEncode, addNoise
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Declare the parameters

# %%
numEpochs = 50
sizeBatch = 32
dimInter = 64
dimEncode = 2
factNoise = 0.2
nameOptim = 'adam'

# %% [markdown]
# ## Load the datasets

# %%
(xTrain, _), (xTest, yTest) = mnist.load_data()
xTrain = xTrain.astype('float32') / 255.
xTest = xTest.astype('float32') / 255.
numTrain = len(xTrain)
numTest = len(xTest)
dimInput = np.prod(xTrain.shape[1:])
sizeDigit = xTrain.shape[1]

xTrain = xTrain.reshape(numTrain, dimInput)
xTest = xTest.reshape(numTest, dimInput)
xTrainNoise = addNoise(xTrain, factNoise=factNoise)
xTestNoise = addNoise(xTest, factNoise=factNoise)
print(xTrain.shape)
print(xTest.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %% [markdown]
# ## Construct the encoder and decoder

# %%
layEncInt = Dense(dimInter, activation='relu')
layEncode = Dense(dimEncode, activation='relu')
layDecInt = Dense(dimInter, activation='relu')
layDecode = Dense(dimInput, activation='sigmoid')

inputs = Input(shape=(dimInput,))
interEncode = layEncInt(inputs)
latent = layEncode(interEncode)
encoder = Model(inputs, latent)

inputLatent = Input(shape=(dimEncode,))
interDecode = layDecInt(inputLatent)
outputs = layDecode(interDecode)
decoder = Model(inputLatent, outputs)

# %% [markdown]
# ## Construct the autoencoder

# %%
autoencoder = Model(inputs, decoder(encoder(inputs)))
autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# model_1 (Model)              (None, 2)                 50370
# _________________________________________________________________
# model_2 (Model)              (None, 784)               51152
# =================================================================
# Total params: 101,522
# Trainable params: 101,522
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compile and train

# %%
autoencoder.compile(optimizer=nameOptim, loss='binary_crossentropy')
tic = time()
history = autoencoder.fit(xTrainNoise, xTrain,
                epochs=numEpochs,
                batch_size=sizeBatch,
                shuffle=True,
                validation_data=(xTest, xTest))
timeTrain = time() - tic
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 10s 162us/step - loss: 0.2405 - val_loss: 0.2533
# Epoch 2/50
# 60000/60000 [==============================] - 7s 112us/step - loss: 0.2137 - val_loss: 0.2288
# Epoch 3/50
# 60000/60000 [==============================] - 7s 111us/step - loss: 0.2084 - val_loss: 0.2186
# Epoch 4/50
# 60000/60000 [==============================] - 7s 112us/step - loss: 0.2049 - val_loss: 0.2152
# Epoch 5/50
# 60000/60000 [==============================] - 7s 111us/step - loss: 0.2023 - val_loss: 0.2102
# Epoch 6/50
# 60000/60000 [==============================] - 7s 111us/step - loss: 0.2004 - val_loss: 0.2071
# Epoch 7/50
# 60000/60000 [==============================] - 7s 112us/step - loss: 0.1990 - val_loss: 0.2060
# Epoch 8/50
# 60000/60000 [==============================] - 7s 111us/step - loss: 0.1978 - val_loss: 0.2042
# Epoch 9/50
# 60000/60000 [==============================] - 7s 113us/step - loss: 0.1968 - val_loss: 0.2035
# Epoch 10/50
# 60000/60000 [==============================] - 7s 111us/step - loss: 0.1960 - val_loss: 0.2036
# Epoch 11/50
# 60000/60000 [==============================] - 7s 112us/step - loss: 0.1953 - val_loss: 0.2034
# Epoch 12/50
# 60000/60000 [==============================] - 7s 112us/step - loss: 0.1947 - val_loss: 0.2020
# Epoch 13/50
# 60000/60000 [==============================] - 7s 112us/step - loss: 0.1942 - val_loss: 0.2014
# Epoch 14/50
# 60000/60000 [==============================] - 7s 110us/step - loss: 0.1937 - val_loss: 0.2008
# Epoch 15/50
# 60000/60000 [==============================] - 7s 112us/step - loss: 0.1932 - val_loss: 0.1998
# Epoch 16/50
# 60000/60000 [==============================] - 7s 111us/step - loss: 0.1928 - val_loss: 0.1993
# Epoch 17/50
# 60000/60000 [==============================] - 7s 113us/step - loss: 0.1923 - val_loss: 0.1984
# Epoch 18/50
# 60000/60000 [==============================] - 7s 111us/step - loss: 0.1920 - val_loss: 0.1980
# Epoch 19/50
# 60000/60000 [==============================] - 7s 111us/step - loss: 0.1917 - val_loss: 0.1979
# Epoch 20/50
# 60000/60000 [==============================] - 7s 112us/step - loss: 0.1913 - val_loss: 0.1981
# Epoch 21/50
# 60000/60000 [==============================] - 7s 111us/step - loss: 0.1910 - val_loss: 0.1971
# Epoch 22/50
# 60000/60000 [==============================] - 7s 111us/step - loss: 0.1907 - val_loss: 0.1966
# Epoch 23/50
# 60000/60000 [==============================] - 7s 112us/step - loss: 0.1904 - val_loss: 0.1969
# Epoch 24/50
# 60000/60000 [==============================] - 7s 114us/step - loss: 0.1902 - val_loss: 0.1964
# Epoch 25/50
# 60000/60000 [==============================] - 7s 111us/step - loss: 0.1900 - val_loss: 0.1964
# Epoch 26/50
# 60000/60000 [==============================] - 7s 111us/step - loss: 0.1898 - val_loss: 0.1974
# Epoch 27/50
# 60000/60000 [==============================] - 7s 112us/step - loss: 0.1896 - val_loss: 0.1976
# Epoch 28/50
# 60000/60000 [==============================] - 7s 110us/step - loss: 0.1893 - val_loss: 0.1970
# Epoch 29/50
# 60000/60000 [==============================] - 7s 111us/step - loss: 0.1892 - val_loss: 0.1980
# Epoch 30/50
# 60000/60000 [==============================] - 7s 113us/step - loss: 0.1890 - val_loss: 0.1980
# Epoch 31/50
# 60000/60000 [==============================] - 7s 112us/step - loss: 0.1888 - val_loss: 0.1966
# Epoch 32/50
# 60000/60000 [==============================] - 7s 111us/step - loss: 0.1887 - val_loss: 0.1966
# Epoch 33/50
# 60000/60000 [==============================] - 7s 111us/step - loss: 0.1885 - val_loss: 0.1966
# Epoch 34/50
# 60000/60000 [==============================] - 7s 113us/step - loss: 0.1884 - val_loss: 0.1965
# Epoch 35/50
# 60000/60000 [==============================] - 7s 112us/step - loss: 0.1882 - val_loss: 0.1966
# Epoch 36/50
# 60000/60000 [==============================] - 7s 112us/step - loss: 0.1881 - val_loss: 0.1968
# Epoch 37/50
# 60000/60000 [==============================] - 7s 111us/step - loss: 0.1879 - val_loss: 0.1962
# Epoch 38/50
# 60000/60000 [==============================] - 7s 112us/step - loss: 0.1878 - val_loss: 0.1958
# Epoch 39/50
# 60000/60000 [==============================] - 7s 112us/step - loss: 0.1876 - val_loss: 0.1959
# Epoch 40/50
# 60000/60000 [==============================] - 7s 111us/step - loss: 0.1875 - val_loss: 0.1964
# Epoch 41/50
# 60000/60000 [==============================] - 7s 113us/step - loss: 0.1874 - val_loss: 0.1952
# Epoch 42/50
# 60000/60000 [==============================] - 7s 115us/step - loss: 0.1873 - val_loss: 0.1965
# Epoch 43/50
# 60000/60000 [==============================] - 7s 112us/step - loss: 0.1872 - val_loss: 0.1963
# Epoch 44/50
# 60000/60000 [==============================] - 7s 111us/step - loss: 0.1870 - val_loss: 0.1952
# Epoch 45/50
# 60000/60000 [==============================] - 7s 113us/step - loss: 0.1870 - val_loss: 0.1959
# Epoch 46/50
# 60000/60000 [==============================] - 7s 112us/step - loss: 0.1869 - val_loss: 0.1962
# Epoch 47/50
# 60000/60000 [==============================] - 7s 112us/step - loss: 0.1868 - val_loss: 0.1955
# Epoch 48/50
# 60000/60000 [==============================] - 7s 112us/step - loss: 0.1866 - val_loss: 0.1952
# Epoch 49/50
# 60000/60000 [==============================] - 7s 111us/step - loss: 0.1865 - val_loss: 0.1968
# Epoch 50/50
# 60000/60000 [==============================] - 7s 112us/step - loss: 0.1865 - val_loss: 0.1958

# %% [markdown]
# ## Show the historical training progress

# %%
print("traing consumed: " + str(timeTrain) + " seconds")
plotProgress(history)
# Out:
# traing consumed: 338.76314663887024 seconds

# %% [markdown]
# ## Get the encoding and decoding results of testing data, and get the mean/std of the encoding

# %%
# encode and decode some digits
# note that we take them from the *test* set
encodeTest = encoder.predict(xTest)
decodeTest = decoder.predict(encodeTest)
meanEncTest = np.mean(encodeTest, axis=0)
stdEncTest = np.std(encodeTest, axis=0)

# %% [markdown]
# ## Compare original digitals with the decoding results

# %%
plotCompDecode(xTest, decodeTest, xNoise=xTestNoise)

# %% [markdown]
# ## Plot the scatter of the encoding space

# %%
xlim = (meanEncTest[0] - 4*stdEncTest[0], meanEncTest[0] + 4*stdEncTest[0])
ylim = (meanEncTest[1] - 4*stdEncTest[1], meanEncTest[1] + 4*stdEncTest[1])

plotScatterEncode(encodeTest, yTest, xlim, ylim, numShow=10000)
scoreSilh = silhouette_score(encodeTest, yTest)

# %% [markdown]
# ## Plot the decoding results from the encoding scatter

# %%
# display a 2D manifold of the digits
plotScatterDecode(decoder, sizeDigit, xlim, ylim)

# %%
print(timeTrain, history.history["loss"][numEpochs-1], history.history["val_loss"][numEpochs-1], scoreSilh)
# Out:
# 338.76314663887024 0.18648048667112987 0.1958265711069107 -0.053624272
