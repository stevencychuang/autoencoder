# %%
from time import time
import numpy as np
numSeed = 42
np.random.seed(numSeed)
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras.datasets import mnist

from util import plotScatterDecode, plotProgress, plotCompDecode, plotScatterEncode, addNoise
# Out:
# c:\users\user\anaconda3\envs\py36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ## Declare the parameters

# %%
numEpochs = 50
sizeBatch = 32
dimInter = 64
dimEncode = 2
factNoise = 0.2
nameOptim = 'adam'

# %% [markdown]
# ## Load the datasets

# %%
(xTrain, _), (xTest, yTest) = mnist.load_data()
xTrain = xTrain.astype('float32') / 255.
xTest = xTest.astype('float32') / 255.
numTrain = len(xTrain)
numTest = len(xTest)
dimInput = np.prod(xTrain.shape[1:])
sizeDigit = xTrain.shape[1]

xTrain = xTrain.reshape(numTrain, dimInput)
xTest = xTest.reshape(numTest, dimInput)
xTrainNoise = addNoise(xTrain, factNoise=factNoise)
xTestNoise = addNoise(xTest, factNoise=factNoise)
print(xTrain.shape)
print(xTest.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %% [markdown]
# ## Construct the encoder and decoder

# %%
layEncInt = Dense(dimInter, activation='relu')
layEncode = Dense(dimEncode, activation='relu')
layDecInt = Dense(dimInter, activation='relu')
layDecode = Dense(dimInput, activation='sigmoid')

inputs = Input(shape=(dimInput,))
interEncode = layEncInt(inputs)
latent = layEncode(interEncode)
encoder = Model(inputs, latent)

inputLatent = Input(shape=(dimEncode,))
interDecode = layDecInt(inputLatent)
outputs = layDecode(interDecode)
decoder = Model(inputLatent, outputs)

# %% [markdown]
# ## Construct the autoencoder

# %%
autoencoder = Model(inputs, decoder(encoder(inputs)))
autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# model_1 (Model)              (None, 2)                 50370
# _________________________________________________________________
# model_2 (Model)              (None, 784)               51152
# =================================================================
# Total params: 101,522
# Trainable params: 101,522
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compile and train

# %%
autoencoder.compile(optimizer=nameOptim, loss='binary_crossentropy')
tic = time()
history = autoencoder.fit(xTrainNoise, xTrain,
                epochs=numEpochs,
                batch_size=sizeBatch,
                shuffle=True,
                validation_data=(xTest, xTest))
timeTrain = time() - tic
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 8s 136us/step - loss: 0.2472 - val_loss: 0.2736
# Epoch 2/50
# 60000/60000 [==============================] - 6s 107us/step - loss: 0.2154 - val_loss: 0.2397
# Epoch 3/50
# 60000/60000 [==============================] - 6s 106us/step - loss: 0.2105 - val_loss: 0.2230
# Epoch 4/50
# 60000/60000 [==============================] - 6s 107us/step - loss: 0.2074 - val_loss: 0.2192
# Epoch 5/50
# 60000/60000 [==============================] - 6s 106us/step - loss: 0.2053 - val_loss: 0.2162
# Epoch 6/50
# 60000/60000 [==============================] - 6s 103us/step - loss: 0.2038 - val_loss: 0.2123
# Epoch 7/50
# 60000/60000 [==============================] - 6s 105us/step - loss: 0.2027 - val_loss: 0.2093
# Epoch 8/50
# 60000/60000 [==============================] - 6s 104us/step - loss: 0.2017 - val_loss: 0.2083
# Epoch 9/50
# 60000/60000 [==============================] - 6s 105us/step - loss: 0.2007 - val_loss: 0.2072
# Epoch 10/50
# 60000/60000 [==============================] - 6s 106us/step - loss: 0.1998 - val_loss: 0.2060
# Epoch 11/50
# 60000/60000 [==============================] - 6s 107us/step - loss: 0.1990 - val_loss: 0.2038
# Epoch 12/50
# 60000/60000 [==============================] - 6s 102us/step - loss: 0.1982 - val_loss: 0.2038
# Epoch 13/50
# 60000/60000 [==============================] - 6s 106us/step - loss: 0.1973 - val_loss: 0.2031
# Epoch 14/50
# 60000/60000 [==============================] - 6s 107us/step - loss: 0.1966 - val_loss: 0.2033
# Epoch 15/50
# 60000/60000 [==============================] - 6s 105us/step - loss: 0.1958 - val_loss: 0.2034
# Epoch 16/50
# 60000/60000 [==============================] - 6s 106us/step - loss: 0.1950 - val_loss: 0.2013
# Epoch 17/50
# 60000/60000 [==============================] - 6s 104us/step - loss: 0.1942 - val_loss: 0.2048
# Epoch 18/50
# 60000/60000 [==============================] - 6s 105us/step - loss: 0.1936 - val_loss: 0.2042
# Epoch 19/50
# 60000/60000 [==============================] - 6s 107us/step - loss: 0.1931 - val_loss: 0.2037
# Epoch 20/50
# 60000/60000 [==============================] - 6s 106us/step - loss: 0.1925 - val_loss: 0.2023
# Epoch 21/50
# 60000/60000 [==============================] - 6s 106us/step - loss: 0.1920 - val_loss: 0.2036
# Epoch 22/50
# 60000/60000 [==============================] - 6s 105us/step - loss: 0.1915 - val_loss: 0.2032
# Epoch 23/50
# 60000/60000 [==============================] - 6s 104us/step - loss: 0.1911 - val_loss: 0.2023
# Epoch 24/50
# 60000/60000 [==============================] - 7s 109us/step - loss: 0.1908 - val_loss: 0.1999
# Epoch 25/50
# 60000/60000 [==============================] - 6s 106us/step - loss: 0.1904 - val_loss: 0.2026
# Epoch 26/50
# 60000/60000 [==============================] - 6s 107us/step - loss: 0.1900 - val_loss: 0.2038
# Epoch 27/50
# 60000/60000 [==============================] - 7s 110us/step - loss: 0.1897 - val_loss: 0.2001
# Epoch 28/50
# 60000/60000 [==============================] - 6s 108us/step - loss: 0.1894 - val_loss: 0.2024
# Epoch 29/50
# 60000/60000 [==============================] - 6s 107us/step - loss: 0.1891 - val_loss: 0.2059
# Epoch 30/50
# 60000/60000 [==============================] - 6s 107us/step - loss: 0.1888 - val_loss: 0.2028
# Epoch 31/50
# 60000/60000 [==============================] - 6s 106us/step - loss: 0.1887 - val_loss: 0.2089
# Epoch 32/50
# 60000/60000 [==============================] - 6s 106us/step - loss: 0.1883 - val_loss: 0.2066
# Epoch 33/50
# 60000/60000 [==============================] - 6s 105us/step - loss: 0.1881 - val_loss: 0.2101
# Epoch 34/50
# 60000/60000 [==============================] - 6s 106us/step - loss: 0.1881 - val_loss: 0.2104
# Epoch 35/50
# 60000/60000 [==============================] - 7s 110us/step - loss: 0.1877 - val_loss: 0.2145
# Epoch 36/50
# 60000/60000 [==============================] - 6s 108us/step - loss: 0.1876 - val_loss: 0.2098
# Epoch 37/50
# 60000/60000 [==============================] - 6s 106us/step - loss: 0.1873 - val_loss: 0.2125
# Epoch 38/50
# 60000/60000 [==============================] - 7s 109us/step - loss: 0.1872 - val_loss: 0.2107
# Epoch 39/50
# 60000/60000 [==============================] - 6s 106us/step - loss: 0.1870 - val_loss: 0.2122
# Epoch 40/50
# 60000/60000 [==============================] - 6s 104us/step - loss: 0.1868 - val_loss: 0.2122
# Epoch 41/50
# 60000/60000 [==============================] - 6s 108us/step - loss: 0.1867 - val_loss: 0.2091
# Epoch 42/50
# 60000/60000 [==============================] - 6s 108us/step - loss: 0.1864 - val_loss: 0.2050
# Epoch 43/50
# 60000/60000 [==============================] - 6s 107us/step - loss: 0.1864 - val_loss: 0.2107
# Epoch 44/50
# 60000/60000 [==============================] - 6s 106us/step - loss: 0.1863 - val_loss: 0.2063
# Epoch 45/50
# 60000/60000 [==============================] - 6s 107us/step - loss: 0.1863 - val_loss: 0.2015
# Epoch 46/50
# 60000/60000 [==============================] - 6s 108us/step - loss: 0.1869 - val_loss: 0.2014 0s - loss: 0.
# Epoch 47/50
# 60000/60000 [==============================] - 6s 108us/step - loss: 0.1861 - val_loss: 0.2117
# Epoch 48/50
# 60000/60000 [==============================] - 6s 107us/step - loss: 0.1860 - val_loss: 0.2106
# Epoch 49/50
# 60000/60000 [==============================] - 6s 106us/step - loss: 0.1859 - val_loss: 0.2038
# Epoch 50/50
# 60000/60000 [==============================] - 6s 106us/step - loss: 0.1860 - val_loss: 0.2227

# %% [markdown]
# ## Show the historical training progress

# %%
print("traing consumed: " + str(timeTrain) + " seconds")
plotProgress(history)
# Out:
# traing consumed: 321.0923409461975 seconds

# %% [markdown]
# ## Get the encoding and decoding results of testing data, and get the mean/std of the encoding

# %%
# encode and decode some digits
# note that we take them from the *test* set
encodeTest = encoder.predict(xTest)
decodeTest = decoder.predict(encodeTest)
meanEncTest = np.mean(encodeTest, axis=0)
stdEncTest = np.std(encodeTest, axis=0)

# %% [markdown]
# ## Compare original digitals with the decoding results

# %%
plotCompDecode(xTest, decodeTest, xNoise=xTestNoise)

# %% [markdown]
# ## Plot the scatter of the encoding space

# %%
xlim = (meanEncTest[0] - 4*stdEncTest[0], meanEncTest[0] + 4*stdEncTest[0])
ylim = (meanEncTest[1] - 4*stdEncTest[1], meanEncTest[1] + 4*stdEncTest[1])

plotScatterEncode(encodeTest, yTest, xlim, ylim, numShow=10000)
scoreSilh = silhouette_score(encodeTest, yTest)

# %% [markdown]
# ## Plot the decoding results from the encoding scatter

# %%
# display a 2D manifold of the digits
plotScatterDecode(decoder, (sizeDigit, sizeDigit), xlim, ylim)

# %%
print(timeTrain, history.history["loss"][numEpochs-1], history.history["val_loss"][numEpochs-1], scoreSilh)
# Out:
# 321.0923409461975 0.18601512188911437 0.2226608892440796 -0.029653816

# %%
np.save("../test/yTest_mnist",yTest)
